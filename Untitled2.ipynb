# %% [markdown]
# <a href="https://colab.research.google.com/github/smeshnayasova61/project/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Для отклика на эту вакансию необходимо ответить на несколько вопросов работодателя.
#
# Чтобы откликнуться на вакансию, необходимо пройти анкетирование.
# Фамилия Имя
# Прокшина Алиса
# Дата рождения
#
#
#
#
#
# Город (в котором сейчас находитесь)
# Номер телефона
# Электронная почта
# Ваше образование (или текущую степень обучения), университет, факультет, специальность
# Расскажите о своих учебных интересах: темы ваших курсовых, дипломной работы, участие в конференциях и научных проектах
# Опишите, какими задачами вам было бы интересно заниматься во время стажировки
#
#
#
#
#
# Расскажите о своих достижениях — медалях, дипломах, сертификатах, выступлениях в качестве спикера, об участии в хакатонах, научных статьях и т.д.
#
#
#
# Есть ли у вас опыт стажировки? Расскажите об этом
#
#
#
# Перечислите другие языки программирования и технологии, которые вы используете (в порядке предпочтения). Оцените уровень владения ими (от 1 до 10)
#
#
#
# Расскажите о себе, почему вам интересна дата аналитика?
# Перед вами небольшая таблица (https://clck.ru/34xJwW), содержащая информацию о покупках (cheque) в интернет-магазине в различных регионах (каждая строка - транзакция). Успешная покупка имеет status, равный 1. Необходимо проанализировать данные и ответить на вопрос:
#
# Укажите регион, с наибольшим средним чеком покупок, совершенных за январь.
#
# Перед вами небольшая таблица (https://clck.ru/34xJwW), содержащая информацию о покупках (cheque) в интернет-магазине в различных регионах (каждая строка - транзакция). Успешная покупка имеет status, равный 1. Необходимо проанализировать данные и ответить на вопрос:
#
# Найдите регион с самым высоким числом успешных покупок за весь заданный период и в ответе укажите число этих покупок.
# Небольшая задача: вероятность того, что вы верно ответите на первый вопрос - 0,9, а вероятность того, что вы верно ответите на второй вопрос - 0,8.
# Определите вероятность того, что вы ответите верно хотя бы на один из двух вопросов.

# %% [markdown]
# Небольшая задача: вероятность того, что вы верно ответите на первый вопрос - 0,9, а вероятность того, что вы верно ответите на второй вопрос - 0,8.
# Определите вероятность того, что вы ответите верно хотя бы на один из двух вопросов.
# https://spb.hh.ru/applicant/vacancy_response?vacancyId=83244359

# %% [markdown]
# Р(А)=0,9
# P(B)=0,8
# P(AB) = P(A) ∙ P(B) = 0,9 * 0,8 = 0,72

# %% [markdown]
# Вероятность того, что вы ответите верно хотя бы на один из двух вопросов=0,72
